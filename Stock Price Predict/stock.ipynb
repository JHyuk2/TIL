# %%
'''

# !pip install finance-datareader
# !pip install pykrx
# !pip install pandas_datareader
# !pip install yfinance

'''
# Out:
# ERROR: Could not find a version that satisfies the requirement FinanceDataReader (from versions: none)
# ERROR: No matching distribution found for FinanceDataReader
# Collecting pykrx
#   Downloading pykrx-1.0.45-py3-none-any.whl.metadata (62 kB)
#      ---------------------------------------- 62.4/62.4 kB ? eta 0:00:00
# Requirement already satisfied: requests in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pykrx) (2.27.1)
# Requirement already satisfied: pandas in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pykrx) (1.4.1)
# Collecting datetime (from pykrx)
#   Downloading DateTime-5.4-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: numpy in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pykrx) (1.26.2)
# Collecting xlrd (from pykrx)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.5/96.5 kB 5.4 MB/s eta 0:00:00
# Collecting deprecated (from pykrx)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting multipledispatch (from pykrx)
#   Downloading multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: matplotlib in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pykrx) (3.5.1)
# Collecting zope.interface (from datetime->pykrx)
#   Downloading zope.interface-6.1-cp310-cp310-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# Requirement already satisfied: pytz in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from datetime->pykrx) (2021.3)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from deprecated->pykrx) (1.14.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pykrx) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pykrx) (4.31.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pykrx) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pykrx) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pykrx) (9.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pykrx) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from matplotlib->pykrx) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests->pykrx) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests->pykrx) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests->pykrx) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests->pykrx) (3.3)
# Requirement already satisfied: six>=1.5 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib->pykrx) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from zope.interface->datetime->pykrx) (58.1.0)
# Downloading pykrx-1.0.45-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 2.2/2.2 MB 35.6 MB/s eta 0:00:00
# Downloading DateTime-5.4-py3-none-any.whl (52 kB)
#    ---------------------------------------- 52.5/52.5 kB ? eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Downloading zope.interface-6.1-cp310-cp310-win_amd64.whl (204 kB)
#    ---------------------------------------- 204.2/204.2 kB ? eta 0:00:00
# Installing collected packages: multipledispatch, zope.interface, xlrd, deprecated, datetime, pykrx
# Successfully installed datetime-5.4 deprecated-1.2.14 multipledispatch-1.0.0 pykrx-1.0.45 xlrd-2.0.1 zope.interface-6.1
# Collecting pandas_datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      -------------------------------------- 109.5/109.5 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: lxml in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pandas_datareader) (4.8.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pandas_datareader) (1.4.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pandas_datareader) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->pandas_datareader) (2021.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.26.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.3)
# Requirement already satisfied: six>=1.5 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas_datareader) (1.16.0)
# Installing collected packages: pandas_datareader
# Successfully installed pandas_datareader-0.10.0
# Collecting yfinance
#   Downloading yfinance-0.2.35-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.4.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from yfinance) (1.26.2)
# Collecting requests>=2.31 (from yfinance)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting lxml>=4.9.1 (from yfinance)
#   Downloading lxml-5.1.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting pytz>=2022.5 (from yfinance)
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.0-cp310-cp310-win_amd64.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.0.tar.gz (2.9 MB)
#      ---------------------------------------- 2.9/2.9 MB 37.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting beautifulsoup4>=4.11.1 (from yfinance)
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      -------------------------------------- 143.0/143.0 kB 8.3 MB/s eta 0:00:00
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ---------------------------------------- 112.2/112.2 kB ? eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dm705\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.31->yfinance) (2021.10.8)
# Downloading yfinance-0.2.35-py2.py3-none-any.whl (72 kB)
#    ---------------------------------------- 72.2/72.2 kB 3.9 MB/s eta 0:00:00
# Downloading frozendict-2.4.0-cp310-cp310-win_amd64.whl (36 kB)
# Downloading lxml-5.1.0-cp310-cp310-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 3.9/3.9 MB 49.9 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    --------------------------------------- 502.5/502.5 kB 30.8 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#    ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.0-py3-none-any.whl size=135766 sha256=e54a0f919a7f252a4762582d65af859345cc024f7572a9c5f5e26bb13308f131
#   Stored in directory: c:\users\dm705\appdata\local\pip\cache\wheels\c7\70\ad\212867e96e7004265a69c4aa5dcff00a95f547a67ba26e7e76
# Successfully built peewee
# Installing collected packages: pytz, peewee, multitasking, appdirs, requests, lxml, html5lib, frozendict, beautifulsoup4, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2021.3
#     Uninstalling pytz-2021.3:
#       Successfully uninstalled pytz-2021.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.8.0
#     Uninstalling lxml-4.8.0:
#       Successfully uninstalled lxml-4.8.0
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.10.0
#     Uninstalling beautifulsoup4-4.10.0:
#       Successfully uninstalled beautifulsoup4-4.10.0
# Successfully installed appdirs-1.4.4 beautifulsoup4-4.12.2 frozendict-2.4.0 html5lib-1.1 lxml-5.1.0 multitasking-0.0.11 peewee-3.17.0 pytz-2023.3.post1 requests-2.31.0 yfinance-0.2.35

# %%
import FinanceDataReader as fdr
from pykrx import stock
import pandas_datareader.data as pdr
import yfinance as yf

# %%
# 한국거래소에 상장된 모든 종목 리스트 가져오기
df_krx = fdr.StockListing("KRX")
df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        73100          2     -100
# 1  000660  KR7000660001    SK하이닉스  KOSPI       134100          2    -1900
# 2  373220  KR7373220003  LG에너지솔루션  KOSPI       413000          2    -2500
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       744000          2    -7000
# 4  005935  KR7005931001     삼성전자우  KOSPI        59800          1      300
#
#    ChagesRatio    Open    High     Low    Volume        Amount  \
# 0        -0.14   73000   74100   72800  13038939  956811865637
# 1        -1.40  136400  137300  133400   1878915  252938171800
# 2        -0.60  415000  415500  409000    151154   62137642680
# 3        -0.93  752000  758000  740000     36332   27142333000
# 4         0.50   59700   60300   59500    676358   40500115408
#
#             Marcap      Stocks MarketId
# 0  436391104405000  5969782550      STK
# 1   97625117146500   728002365      STK
# 2   96642000000000   234000000      STK
# 3   52953456000000    71174000      STK
# 4   49208624660000   822886700      STK

# %%
# S&P 500에 등록된 모든 종목 리스트 가져오기
df_spx = fdr.StockListing('S&P500')
df_spx.head()
# Out:
#   Symbol         Name                  Sector                        Industry
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                   Biotechnology
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services

# %%
# 한국거래소에 상장된 종목의 가격 데이터 가져오기
df = fdr.DataReader(symbol='005930', start='2020') # 삼성전자, 2020년~현재
df
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2020-01-02  55500  56000  55000  55200  12993228 -0.010753
# 2020-01-03  56000  56600  54900  55500  15422255  0.005435
# 2020-01-06  54900  55600  54600  55500  10278951  0.000000
# 2020-01-07  55700  56400  55600  55800  10009778  0.005405
# 2020-01-08  56200  57400  55900  56800  23501171  0.017921
# ...           ...    ...    ...    ...       ...       ...
# 2024-01-08  77000  77500  76400  76500  11088724 -0.001305
# 2024-01-09  77400  77700  74300  74700  26019249 -0.023529
# 2024-01-10  75000  75200  73200  73600  20259529 -0.014726
# 2024-01-11  72900  73600  72700  73200  57691266 -0.005435
# 2024-01-12  73000  74100  72800  73100  12970027 -0.001366
#
# [996 rows x 6 columns]

# %%
help()
# Out:
# Help on function DataReader in module FinanceDataReader.data:
#
# DataReader(symbol: str, start=None, end=None, exchange=None, data_source=None) -> pandas.core.frame.DataFrame
#     read price data (timeseries) from various exchanges or data source
#     - symbol: code or ticker (with exchange: 'KRX'(default), 'KRX-DETAIL', 'KRX-DELISTING', 'NAVER', 'YAHOO' ...)
#     - start: datetime or str
#     - end: datetime or str
#
#     usage:
#         - fdr.DataReader('KRX:KOSPI', '2020')
#         - fdr.DataReader('ECOS:한국은행기준금리', '1990-01-01')
